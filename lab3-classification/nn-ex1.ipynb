# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

from itertools import cycle
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import auc, roc_curve, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

import tensorflow as tf
from tensorflow import keras
from keras.datasets import mnist
from keras.utils import to_categorical

# %% [markdown]
# ## Load dataset

# %%
(train_X, train_y), (test_X, test_y) = mnist.load_data()

# %%
new_shape = train_X[0].shape[0] * train_X[0].shape[1]
train_X = train_X / 255
test_X = test_X / 255

# %%
train_X = train_X.reshape(train_X.shape[0],
                         new_shape)
test_X = test_X.reshape(test_X.shape[0],
                         new_shape)

# %%
train_X.shape
# Out:
# (60000, 784)

# %%
_train_y = np.array(train_y)
_train_y = to_categorical(_train_y)

# %% [markdown]
# ## Create NN

# %%
inputs = keras.layers.Input(shape=(train_X.shape[1],), name='input')
outputs = keras.layers.Dense(10, activation='softmax', name='output')(inputs)

# %%
neural_net = keras.Model(inputs=[inputs], outputs=[outputs])

# %%
neural_net.compile(optimizer=keras.optimizers.SGD(), loss='categorical_crossentropy', metrics=[tf.keras.metrics.AUC()])
neural_net.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 784)]             0
#
#  output (Dense)              (None, 10)                7850
#
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_monitoring = neural_net.fit(x=train_X, y=_train_y, validation_split=.20, shuffle=True, batch_size=64, epochs=100)
# Out:
# Epoch 1/100
# 750/750 [==============================] - 1s 1ms/step - loss: 1.0803 - auc: 0.9584 - val_loss: 0.6508 - val_auc: 0.9857
# Epoch 2/100
# 750/750 [==============================] - 1s 726us/step - loss: 0.6052 - auc: 0.9850 - val_loss: 0.5045 - val_auc: 0.9887
# Epoch 3/100
# 750/750 [==============================] - 1s 727us/step - loss: 0.5107 - auc: 0.9875 - val_loss: 0.4474 - val_auc: 0.9898
# Epoch 4/100
# 750/750 [==============================] - 1s 734us/step - loss: 0.4649 - auc: 0.9887 - val_loss: 0.4158 - val_auc: 0.9903
# Epoch 5/100
# 750/750 [==============================] - 1s 758us/step - loss: 0.4366 - auc: 0.9893 - val_loss: 0.3956 - val_auc: 0.9908
# Epoch 6/100
# 750/750 [==============================] - 1s 858us/step - loss: 0.4172 - auc: 0.9898 - val_loss: 0.3799 - val_auc: 0.9911
# Epoch 7/100
# 750/750 [==============================] - 1s 886us/step - loss: 0.4025 - auc: 0.9901 - val_loss: 0.3686 - val_auc: 0.9912
# Epoch 8/100
# 750/750 [==============================] - 1s 867us/step - loss: 0.3908 - auc: 0.9904 - val_loss: 0.3599 - val_auc: 0.9914
# Epoch 9/100
# 750/750 [==============================] - 1s 776us/step - loss: 0.3816 - auc: 0.9906 - val_loss: 0.3524 - val_auc: 0.9916
# Epoch 10/100
# 750/750 [==============================] - 1s 741us/step - loss: 0.3738 - auc: 0.9908 - val_loss: 0.3462 - val_auc: 0.9917
# Epoch 11/100
# 750/750 [==============================] - 1s 812us/step - loss: 0.3671 - auc: 0.9909 - val_loss: 0.3411 - val_auc: 0.9918
# Epoch 12/100
# 750/750 [==============================] - 1s 932us/step - loss: 0.3613 - auc: 0.9910 - val_loss: 0.3365 - val_auc: 0.9918
# Epoch 13/100
# 750/750 [==============================] - 1s 822us/step - loss: 0.3563 - auc: 0.9912 - val_loss: 0.3326 - val_auc: 0.9919
# Epoch 14/100
# 750/750 [==============================] - 1s 850us/step - loss: 0.3517 - auc: 0.9912 - val_loss: 0.3292 - val_auc: 0.9919
# Epoch 15/100
# 750/750 [==============================] - 1s 809us/step - loss: 0.3478 - auc: 0.9913 - val_loss: 0.3262 - val_auc: 0.9919
# Epoch 16/100
# 750/750 [==============================] - 1s 805us/step - loss: 0.3442 - auc: 0.9914 - val_loss: 0.3233 - val_auc: 0.9920
# Epoch 17/100
# 750/750 [==============================] - 1s 776us/step - loss: 0.3408 - auc: 0.9915 - val_loss: 0.3206 - val_auc: 0.9921
# Epoch 18/100
# 750/750 [==============================] - 1s 725us/step - loss: 0.3378 - auc: 0.9916 - val_loss: 0.3185 - val_auc: 0.9922
# Epoch 19/100
# 750/750 [==============================] - 1s 744us/step - loss: 0.3351 - auc: 0.9916 - val_loss: 0.3163 - val_auc: 0.9923
# Epoch 20/100
# 750/750 [==============================] - 1s 742us/step - loss: 0.3325 - auc: 0.9917 - val_loss: 0.3144 - val_auc: 0.9923
# Epoch 21/100
# 750/750 [==============================] - 1s 724us/step - loss: 0.3301 - auc: 0.9918 - val_loss: 0.3125 - val_auc: 0.9923
# Epoch 22/100
# 750/750 [==============================] - 1s 787us/step - loss: 0.3279 - auc: 0.9918 - val_loss: 0.3107 - val_auc: 0.9923
# Epoch 23/100
# 750/750 [==============================] - 1s 742us/step - loss: 0.3258 - auc: 0.9919 - val_loss: 0.3092 - val_auc: 0.9924
# Epoch 24/100
# 750/750 [==============================] - 1s 739us/step - loss: 0.3239 - auc: 0.9919 - val_loss: 0.3076 - val_auc: 0.9925
# Epoch 25/100
# 750/750 [==============================] - 1s 727us/step - loss: 0.3220 - auc: 0.9919 - val_loss: 0.3066 - val_auc: 0.9925
# Epoch 26/100
# 750/750 [==============================] - 1s 747us/step - loss: 0.3203 - auc: 0.9920 - val_loss: 0.3051 - val_auc: 0.9925
# Epoch 27/100
# 750/750 [==============================] - 1s 733us/step - loss: 0.3188 - auc: 0.9920 - val_loss: 0.3038 - val_auc: 0.9925
# Epoch 28/100
# 750/750 [==============================] - 1s 749us/step - loss: 0.3172 - auc: 0.9921 - val_loss: 0.3027 - val_auc: 0.9925
# Epoch 29/100
# 750/750 [==============================] - 1s 723us/step - loss: 0.3157 - auc: 0.9921 - val_loss: 0.3018 - val_auc: 0.9926
# Epoch 30/100
# 750/750 [==============================] - 1s 725us/step - loss: 0.3144 - auc: 0.9922 - val_loss: 0.3007 - val_auc: 0.9926
# Epoch 31/100
# 750/750 [==============================] - 1s 784us/step - loss: 0.3131 - auc: 0.9922 - val_loss: 0.2995 - val_auc: 0.9926
# Epoch 32/100
# 750/750 [==============================] - 1s 775us/step - loss: 0.3118 - auc: 0.9922 - val_loss: 0.2987 - val_auc: 0.9927
# Epoch 33/100
# 750/750 [==============================] - 1s 755us/step - loss: 0.3106 - auc: 0.9923 - val_loss: 0.2977 - val_auc: 0.9926
# Epoch 34/100
# 750/750 [==============================] - 1s 791us/step - loss: 0.3094 - auc: 0.9923 - val_loss: 0.2969 - val_auc: 0.9926
# Epoch 35/100
# 750/750 [==============================] - 1s 919us/step - loss: 0.3083 - auc: 0.9923 - val_loss: 0.2962 - val_auc: 0.9927
# Epoch 36/100
# 750/750 [==============================] - 1s 782us/step - loss: 0.3073 - auc: 0.9923 - val_loss: 0.2955 - val_auc: 0.9928
# Epoch 37/100
# 750/750 [==============================] - 1s 788us/step - loss: 0.3063 - auc: 0.9924 - val_loss: 0.2945 - val_auc: 0.9927
# Epoch 38/100
# 750/750 [==============================] - 1s 782us/step - loss: 0.3053 - auc: 0.9924 - val_loss: 0.2939 - val_auc: 0.9927
# Epoch 39/100
# 750/750 [==============================] - 1s 897us/step - loss: 0.3043 - auc: 0.9924 - val_loss: 0.2935 - val_auc: 0.9927
# Epoch 40/100
# 750/750 [==============================] - 1s 924us/step - loss: 0.3035 - auc: 0.9925 - val_loss: 0.2925 - val_auc: 0.9927
# Epoch 41/100
# 750/750 [==============================] - 1s 827us/step - loss: 0.3025 - auc: 0.9925 - val_loss: 0.2922 - val_auc: 0.9927
# Epoch 42/100
# 750/750 [==============================] - 1s 868us/step - loss: 0.3018 - auc: 0.9925 - val_loss: 0.2914 - val_auc: 0.9927
# Epoch 43/100
# 750/750 [==============================] - 1s 871us/step - loss: 0.3009 - auc: 0.9925 - val_loss: 0.2910 - val_auc: 0.9927
# Epoch 44/100
# 750/750 [==============================] - 1s 775us/step - loss: 0.3001 - auc: 0.9926 - val_loss: 0.2904 - val_auc: 0.9928
# Epoch 45/100
# 750/750 [==============================] - 1s 924us/step - loss: 0.2994 - auc: 0.9926 - val_loss: 0.2897 - val_auc: 0.9928
# Epoch 46/100
# 750/750 [==============================] - 1s 838us/step - loss: 0.2986 - auc: 0.9926 - val_loss: 0.2891 - val_auc: 0.9928
# Epoch 47/100
# 750/750 [==============================] - 1s 752us/step - loss: 0.2980 - auc: 0.9927 - val_loss: 0.2888 - val_auc: 0.9927
# Epoch 48/100
# 750/750 [==============================] - 1s 814us/step - loss: 0.2972 - auc: 0.9926 - val_loss: 0.2884 - val_auc: 0.9927
# Epoch 49/100
# 750/750 [==============================] - 1s 814us/step - loss: 0.2966 - auc: 0.9926 - val_loss: 0.2879 - val_auc: 0.9929
# Epoch 50/100
# 750/750 [==============================] - 1s 797us/step - loss: 0.2959 - auc: 0.9927 - val_loss: 0.2871 - val_auc: 0.9928
# Epoch 51/100
# 750/750 [==============================] - 1s 960us/step - loss: 0.2953 - auc: 0.9927 - val_loss: 0.2869 - val_auc: 0.9928
# Epoch 52/100
# 750/750 [==============================] - 1s 845us/step - loss: 0.2947 - auc: 0.9927 - val_loss: 0.2865 - val_auc: 0.9928
# Epoch 53/100
# 750/750 [==============================] - 1s 842us/step - loss: 0.2940 - auc: 0.9927 - val_loss: 0.2860 - val_auc: 0.9928
# Epoch 54/100
# 750/750 [==============================] - 1s 865us/step - loss: 0.2935 - auc: 0.9927 - val_loss: 0.2857 - val_auc: 0.9928
# Epoch 55/100
# 750/750 [==============================] - 1s 843us/step - loss: 0.2930 - auc: 0.9927 - val_loss: 0.2853 - val_auc: 0.9928
# Epoch 56/100
# 750/750 [==============================] - 1s 927us/step - loss: 0.2924 - auc: 0.9928 - val_loss: 0.2850 - val_auc: 0.9928
# Epoch 57/100
# 750/750 [==============================] - 1s 910us/step - loss: 0.2919 - auc: 0.9928 - val_loss: 0.2845 - val_auc: 0.9928
# Epoch 58/100
# 750/750 [==============================] - 1s 909us/step - loss: 0.2914 - auc: 0.9928 - val_loss: 0.2840 - val_auc: 0.9927
# Epoch 59/100
# 750/750 [==============================] - 1s 840us/step - loss: 0.2908 - auc: 0.9928 - val_loss: 0.2840 - val_auc: 0.9927
# Epoch 60/100
# 750/750 [==============================] - 1s 869us/step - loss: 0.2903 - auc: 0.9928 - val_loss: 0.2835 - val_auc: 0.9927
# Epoch 61/100
# 750/750 [==============================] - 1s 866us/step - loss: 0.2898 - auc: 0.9928 - val_loss: 0.2831 - val_auc: 0.9928
# Epoch 62/100
# 750/750 [==============================] - 1s 1ms/step - loss: 0.2894 - auc: 0.9928 - val_loss: 0.2828 - val_auc: 0.9928
# Epoch 63/100
# 750/750 [==============================] - 1s 1ms/step - loss: 0.2888 - auc: 0.9928 - val_loss: 0.2825 - val_auc: 0.9927
# Epoch 64/100
# 750/750 [==============================] - 1s 941us/step - loss: 0.2884 - auc: 0.9929 - val_loss: 0.2822 - val_auc: 0.9927
# Epoch 65/100
# 750/750 [==============================] - 1s 953us/step - loss: 0.2880 - auc: 0.9928 - val_loss: 0.2821 - val_auc: 0.9926
# Epoch 66/100
# 750/750 [==============================] - 1s 1ms/step - loss: 0.2875 - auc: 0.9929 - val_loss: 0.2818 - val_auc: 0.9926
# Epoch 67/100
# 750/750 [==============================] - 1s 1ms/step - loss: 0.2871 - auc: 0.9929 - val_loss: 0.2814 - val_auc: 0.9927
# Epoch 68/100
# 750/750 [==============================] - 1s 843us/step - loss: 0.2867 - auc: 0.9929 - val_loss: 0.2811 - val_auc: 0.9927
# Epoch 69/100
# 750/750 [==============================] - 1s 785us/step - loss: 0.2863 - auc: 0.9929 - val_loss: 0.2810 - val_auc: 0.9927
# Epoch 70/100
# 750/750 [==============================] - 1s 767us/step - loss: 0.2859 - auc: 0.9929 - val_loss: 0.2805 - val_auc: 0.9927
# Epoch 71/100
# 750/750 [==============================] - 1s 782us/step - loss: 0.2855 - auc: 0.9929 - val_loss: 0.2803 - val_auc: 0.9926
# Epoch 72/100
# 750/750 [==============================] - 1s 760us/step - loss: 0.2851 - auc: 0.9929 - val_loss: 0.2801 - val_auc: 0.9927
# Epoch 73/100
# 750/750 [==============================] - 1s 750us/step - loss: 0.2847 - auc: 0.9929 - val_loss: 0.2801 - val_auc: 0.9927
# Epoch 74/100
# 750/750 [==============================] - 1s 807us/step - loss: 0.2843 - auc: 0.9929 - val_loss: 0.2796 - val_auc: 0.9927
# Epoch 75/100
# 750/750 [==============================] - 1s 752us/step - loss: 0.2840 - auc: 0.9929 - val_loss: 0.2794 - val_auc: 0.9927
# Epoch 76/100
# 750/750 [==============================] - 1s 813us/step - loss: 0.2836 - auc: 0.9930 - val_loss: 0.2793 - val_auc: 0.9927
# Epoch 77/100
# 750/750 [==============================] - 1s 769us/step - loss: 0.2833 - auc: 0.9929 - val_loss: 0.2790 - val_auc: 0.9927
# Epoch 78/100
# 750/750 [==============================] - 1s 748us/step - loss: 0.2828 - auc: 0.9930 - val_loss: 0.2791 - val_auc: 0.9927
# Epoch 79/100
# 750/750 [==============================] - 1s 1ms/step - loss: 0.2826 - auc: 0.9930 - val_loss: 0.2786 - val_auc: 0.9927
# Epoch 80/100
# 750/750 [==============================] - 1s 885us/step - loss: 0.2822 - auc: 0.9930 - val_loss: 0.2783 - val_auc: 0.9927
# Epoch 81/100
# 750/750 [==============================] - 1s 758us/step - loss: 0.2818 - auc: 0.9930 - val_loss: 0.2785 - val_auc: 0.9927
# Epoch 82/100
# 750/750 [==============================] - 1s 787us/step - loss: 0.2816 - auc: 0.9930 - val_loss: 0.2779 - val_auc: 0.9927
# Epoch 83/100
# 750/750 [==============================] - 1s 795us/step - loss: 0.2813 - auc: 0.9931 - val_loss: 0.2777 - val_auc: 0.9927
# Epoch 84/100
# 750/750 [==============================] - 1s 753us/step - loss: 0.2809 - auc: 0.9930 - val_loss: 0.2776 - val_auc: 0.9927
# Epoch 85/100
# 750/750 [==============================] - 1s 756us/step - loss: 0.2807 - auc: 0.9930 - val_loss: 0.2774 - val_auc: 0.9928
# Epoch 86/100
# 750/750 [==============================] - 1s 770us/step - loss: 0.2803 - auc: 0.9931 - val_loss: 0.2772 - val_auc: 0.9927
# Epoch 87/100
# 750/750 [==============================] - 1s 800us/step - loss: 0.2800 - auc: 0.9931 - val_loss: 0.2772 - val_auc: 0.9927
# Epoch 88/100
# 750/750 [==============================] - 1s 782us/step - loss: 0.2797 - auc: 0.9930 - val_loss: 0.2770 - val_auc: 0.9927
# Epoch 89/100
# 750/750 [==============================] - 1s 770us/step - loss: 0.2795 - auc: 0.9931 - val_loss: 0.2767 - val_auc: 0.9927
# Epoch 90/100
# 750/750 [==============================] - 1s 747us/step - loss: 0.2792 - auc: 0.9930 - val_loss: 0.2765 - val_auc: 0.9927
# Epoch 91/100
# 750/750 [==============================] - 1s 749us/step - loss: 0.2789 - auc: 0.9931 - val_loss: 0.2764 - val_auc: 0.9927
# Epoch 92/100
# 750/750 [==============================] - 1s 761us/step - loss: 0.2786 - auc: 0.9931 - val_loss: 0.2764 - val_auc: 0.9928
# Epoch 93/100
# 750/750 [==============================] - 1s 773us/step - loss: 0.2783 - auc: 0.9931 - val_loss: 0.2760 - val_auc: 0.9927
# Epoch 94/100
# 750/750 [==============================] - 1s 763us/step - loss: 0.2780 - auc: 0.9931 - val_loss: 0.2761 - val_auc: 0.9928
# Epoch 95/100
# 750/750 [==============================] - 1s 735us/step - loss: 0.2778 - auc: 0.9931 - val_loss: 0.2757 - val_auc: 0.9928
# Epoch 96/100
# 750/750 [==============================] - 1s 744us/step - loss: 0.2775 - auc: 0.9931 - val_loss: 0.2755 - val_auc: 0.9928
# Epoch 97/100
# 750/750 [==============================] - 1s 736us/step - loss: 0.2773 - auc: 0.9931 - val_loss: 0.2753 - val_auc: 0.9928
# Epoch 98/100
# 750/750 [==============================] - 1s 739us/step - loss: 0.2770 - auc: 0.9931 - val_loss: 0.2755 - val_auc: 0.9928
# Epoch 99/100
# 750/750 [==============================] - 1s 800us/step - loss: 0.2767 - auc: 0.9931 - val_loss: 0.2755 - val_auc: 0.9928
# Epoch 100/100
# 750/750 [==============================] - 1s 806us/step - loss: 0.2765 - auc: 0.9932 - val_loss: 0.2750 - val_auc: 0.9928

# %%
train_pred_y = neural_net.predict(train_X)
test_pred_y = neural_net.predict(test_X)
# Out:
# 1875/1875 [==============================] - 1s 462us/step
# 313/313 [==============================] - 0s 505us/step

# %% [markdown]
# ## Metrics

# %%
classes = np.unique(test_y).tolist()

# %%
test_pred_y = test_pred_y.tolist()
test_pred_y = np.array([np.argmax(pred) for pred in test_pred_y])

train_pred_y = train_pred_y.tolist()
train_pred_y = np.array([np.argmax(pred) for pred in train_pred_y])

# %%
fig, axis = plt.subplots(1, 2, figsize=(12, 5), sharey='row')

cm = confusion_matrix(train_y, train_pred_y, labels=classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
axis[0].set_title("Train Dataset")
disp.plot(ax=axis[0])

cm = confusion_matrix(test_y, test_pred_y, labels=classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
axis[1].set_title("Test Dataset")
disp.plot(ax=axis[1])

plt.tight_layout()
plt.show()

# %%
onehot_encoder = OneHotEncoder(sparse=False)
test_y = test_y.reshape(len(test_y), 1)
test_y = onehot_encoder.fit_transform(test_y)

train_y = train_y.reshape(len(train_y), 1)
train_y = onehot_encoder.fit_transform(train_y)

test_pred_y = test_pred_y.reshape(len(test_pred_y), 1)
test_pred_y = onehot_encoder.fit_transform(test_pred_y)

train_pred_y = train_pred_y.reshape(len(train_pred_y), 1)
train_pred_y = onehot_encoder.fit_transform(train_pred_y)

# %%
colors = cycle(['darkorange', 'indianred', 'darkkhaki', 'olive', 'lawngreen', 'turquoise', 'teal', 'dodgerblue', 'plum', 'crimson'])


fpr = dict()
tpr = dict()
roc_auc = dict()
lw=2

for i in range(len(classes)):
    fpr[i], tpr[i], _ = roc_curve(train_y[:, i], train_pred_y[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fig = plt.figure(figsize=(24, 8))
for i, color in zip(range(len(classes)), colors):
    plt.subplot(2, 5, i+1)
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,label='ROC curve of class {0} (area = {1:0.2f})'.format(i, roc_auc[i]))
    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f"Train ROC Curve for multi-class data (class {i})")
    plt.legend(loc="lower right")
plt.tight_layout()
plt.show()

fpr = dict()
tpr = dict()
roc_auc = dict()
lw=2

for i in range(len(classes)):
    fpr[i], tpr[i], _ = roc_curve(test_y[:, i], test_pred_y[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fig = plt.figure(figsize=(24, 8))
for i, color in zip(range(len(classes)), colors):
    plt.subplot(2, 5, i+1)
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,label='ROC curve of class {0} (area = {1:0.2f})'.format(i, roc_auc[i]))
    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f"Test ROC Curve for multi-class data (class {i})")
    plt.legend(loc="lower right")
plt.tight_layout()
plt.show()
